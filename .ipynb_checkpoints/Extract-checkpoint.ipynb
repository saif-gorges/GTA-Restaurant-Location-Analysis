# %%
#import dependencies
import pandas as pd

# %%
#read resources
restaurant_data = pd.read_csv("Final_Data2.csv")

# %%
#convery to dataframe
restaurant_df = pd.DataFrame(restaurant_data)
restaurant_df.head()
# Out:
#    Unnamed: 0         Neighbourhood  Hood_ID  Assault Rate  Auto Theft Rate  \
# 0           0        South Parkdale       85        1148.8             91.5
# 1           1       South Riverdale       70         936.3            143.5
# 2           2  St.Andrew-Windfields       40         325.6            196.5
# 3           3         Taylor-Massey       61         777.9             76.5
# 4           4         Humber Summit       21         950.4           1087.3
#
#    Break&Enter Rate  Homicide Rate  Robberey Rate  Theft Over Rate  \
# 0             407.3            4.6          151.0            100.7
# 1             477.1            0.0          125.6             75.3
# 2             466.0            0.0           67.4             33.7
# 3             401.7            6.4           82.9             19.1
# 4             459.1           24.2          225.5            177.2
#
#    Total Average Rate  ...  Percentage of Dwellings Built in 1990 or Before  \
# ...
