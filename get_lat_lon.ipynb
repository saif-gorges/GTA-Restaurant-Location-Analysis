# %% [markdown]
# ### To find latitude & longitude of Toronto (required to use Foursquare API)

# %%
from geopy.geocoders import Nominatim

# %%
address = 'Newtonbrook East'

geolocator = Nominatim(user_agent="geoapi")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(f'Toronto latitude: {latitude}, longitude: {longitude}')
# Out:
# Toronto latitude: 43.7938863, longitude: -79.42567902301055

# %%
address = 'Banbury-Don Mills'

geolocator = Nominatim(user_agent="geoapi")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(f'Toronto latitude: {latitude}, longitude: {longitude}')
# Out:
# Toronto latitude: 43.7526832, longitude: -79.3652703

# %%
import pandas as pd

# %%
neighbourhood_df = pd.read_csv('Resources/data.csv')

list(neighbourhood_df['neighbourhood'])
# Out:
# ['Waterfront Communities-The Island',
#  'Newtonbrook East',
#  'York University Heights',
#  'Dorset Park',
#  'Englemount-lawrence',
#  'Bay Street Corridor',
#  'Yorkdale-glen Park',
#  'Agincourt South-malvern West',
#  'Stonegate-queensway',
#  'Parkwoods-donalda',
#  'South Riverdale',
#  'Newtonbrook West',
#  'Church-yonge Corridor',
#  'Mount Olive-silverstone-jamestown',
#  'Casa Loma',
#  'Downsview-roding-cfb',
#  'South Riverdale',
#  'Kennedy Park',
#  'Agincourt South-malvern West',
#  'York University Heights',
#  'Rouge',
#  'Princess-rosethorn',
#  'Willowdale West',
#  'Bayview Village',
#  'Mimico',
#  'Willowdale East',
#  'Henry Farm',
#  'Agincourt North',
#  'Willowdale East',
#  'Edenbridge-humber Valley',
#  'Englemount-lawrence',
#  'Pleasant View',
#  'West Humber-clairville',
#  'Banbury-don Mills',
#  'Woburn',
#  'Mimico',
#  'Mimico',
#  'Agincourt North',
#  'Church-yonge Corridor',
#  'Bay Street Corridor',
#  'West Hill',
#  'Etobicoke West Mall',
# ...
